# %% [markdown]
# # Geocoding
#
#
# Geocoding is the conversion of addresses into geographic coordinates, typically `latitude and longitude`. It enables mapping and location-based services by associating a physical location with a given address. Reverse geocoding, on the other hand, does the opposite, translating coordinates back into a human-readable address.

# %%
import numpy as np 
import pandas as pd 
import folium 
from folium import Marker
from geopy.geocoders import Nominatim

# %%
data = {
    'Capital': ['Washington, D.C.', 'Ottawa', 'Berlin', 'Paris', 'Tokyo', 'New Delhi', 'Brasília', 'Canberra', 'Beijing', 'Pretoria'],
}

# Create a Pandas DataFrame
df = pd.DataFrame(data)

# df.loc[len(df)] = {'Capital': abc}

df
# Out:
#             Capital
# 0  Washington, D.C.
# 1            Ottawa
# 2            Berlin
# 3             Paris
# 4             Tokyo
# 5         New Delhi
# 6          Brasília
# 7          Canberra
# 8           Beijing
# 9          Pretoria

# %%
geolocator = Nominatim(user_agent="notebook")

for index,row in df.iterrows():
    try:
        df.loc[index,'Country'] = geolocator.geocode(row[0]).address.split(',')[-1].strip()
        df.loc[index,'Latitude'] = geolocator.geocode(row[0]).point.latitude
        df.loc[index,'Longitude'] = geolocator.geocode(row[0]).point.longitude
    except Exception as e:
        print(e)
    
df
# Out:
#             Capital        Country   Latitude   Longitude
# 0  Washington, D.C.  United States  38.895037  -77.036543
# 1            Ottawa         Canada  45.420878  -75.690111
# 2            Berlin    Deutschland  52.517037   13.388860
# 3             Paris         France  48.853495    2.348391
# 4             Tokyo             日本  35.684057  139.774491
# 5         New Delhi          India  28.613895   77.209006
# 6          Brasília         Brasil -10.333333  -53.200000
# 7          Canberra      Australia -35.297591  149.101268
# 8           Beijing             中国  39.905714  116.391297
# 9          Pretoria   South Africa -25.745928   28.187910

# %% [markdown]
#
# for interactive map please click here:(https://nbviewer.org/github/arunrajks/geospatial_analysis/blob/main/geocoding-with-nominatim.ipynb)

# %%
m=folium.Map(location=[0,0],zoom_start=2)

for index,row in df.iterrows():
    Marker(location=[row.Latitude,row.Longitude],popup=row.Capital,).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5bfa1793606ecc4b88a3351d2694ddfb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5bfa1793606ecc4b88a3351d2694ddfb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5bfa1793606ecc4b88a3351d2694ddfb = L.map(
#                 &quot;map_5bfa1793606ecc4b88a3351d2694ddfb&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3ecf26de6746034eeba77918311b1b4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5bfa1793606ecc4b88a3351d2694ddfb);
#
#
#             var marker_2b038762258ac4ea7a9c268347f7ba71 = L.marker(
#                 [38.8950368, -77.0365427],
#                 {}
#             ).addTo(map_5bfa1793606ecc4b88a3351d2694ddfb);
#
#
#         var popup_7f7911f5d74ef1fcc8d10fe8eba92455 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac55928248f35cc924389dede07edd9e = $(`&lt;div id=&quot;html_ac55928248f35cc924389dede07edd9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Washington, D.C.&lt;/div&gt;`)[0];
#                 popup_7f7911f5d74ef1fcc8d10fe8eba92455.setContent(html_ac55928248f35cc924389dede07edd9e);
#
#
#
#         marker_2b038762258ac4ea7a9c268347f7ba71.bindPopup(popup_7f7911f5d74ef1fcc8d10fe8eba92455)
#         ;
#
#
#
#
#             var marker_38e335d56564afafa050a5bc13c3fac3 = L.marker(
#                 [45.4208777, -75.6901106],
#                 {}
#             ).addTo(map_5bfa1793606ecc4b88a3351d2694ddfb);
#
#
#         var popup_6d3fb3fcfa943ef9e44371a9a507d3f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2dd5621aa9d5b1e5835cb7fffe913c42 = $(`&lt;div id=&quot;html_2dd5621aa9d5b1e5835cb7fffe913c42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ottawa&lt;/div&gt;`)[0];
#                 popup_6d3fb3fcfa943ef9e44371a9a507d3f0.setContent(html_2dd5621aa9d5b1e5835cb7fffe913c42);
#
#
#
#         marker_38e335d56564afafa050a5bc13c3fac3.bindPopup(popup_6d3fb3fcfa943ef9e44371a9a507d3f0)
#         ;
#
#
#
#
#             var marker_36a52749c40f5246a6448ff4f114c89f = L.marker(
#                 [52.5170365, 13.3888599],
#                 {}
#             ).addTo(map_5bfa1793606ecc4b88a3351d2694ddfb);
#
#
#         var popup_f99c601ab57df0488e79aa58227657cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f67d516d1ee1d94d340df1444154e46 = $(`&lt;div id=&quot;html_7f67d516d1ee1d94d340df1444154e46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_f99c601ab57df0488e79aa58227657cc.setContent(html_7f67d516d1ee1d94d340df1444154e46);
#
#
#
#         marker_36a52749c40f5246a6448ff4f114c89f.bindPopup(popup_f99c601ab57df0488e79aa58227657cc)
#         ;
#
#
#
#
#             var marker_d8e806b3841583f33a411248e3d07492 = L.marker(
#                 [48.8534951, 2.3483915],
#                 {}
#             ).addTo(map_5bfa1793606ecc4b88a3351d2694ddfb);
#
#
#         var popup_aea06dad220f73f467ded26df711329a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_18a9db3f6e4520b1a8363a8f54adcc71 = $(`&lt;div id=&quot;html_18a9db3f6e4520b1a8363a8f54adcc71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Paris&lt;/div&gt;`)[0];
#                 popup_aea06dad220f73f467ded26df711329a.setContent(html_18a9db3f6e4520b1a8363a8f54adcc71);
#
#
#
#         marker_d8e806b3841583f33a411248e3d07492.bindPopup(popup_aea06dad220f73f467ded26df711329a)
#         ;
#
#
#
#
#             var marker_47291e7b80770900fc926ebcfe01c433 = L.marker(
#                 [35.6840574, 139.7744912],
#                 {}
#             ).addTo(map_5bfa1793606ecc4b88a3351d2694ddfb);
#
#
#         var popup_78e85f02c467cdab1316f1c75ae8ffb2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eefba304549f226eed822bd98c376197 = $(`&lt;div id=&quot;html_eefba304549f226eed822bd98c376197&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tokyo&lt;/div&gt;`)[0];
#                 popup_78e85f02c467cdab1316f1c75ae8ffb2.setContent(html_eefba304549f226eed822bd98c376197);
#
#
#
#         marker_47291e7b80770900fc926ebcfe01c433.bindPopup(popup_78e85f02c467cdab1316f1c75ae8ffb2)
#         ;
#
#
#
#
#             var marker_7a62e552bf6cf5946ceb894eebb633e5 = L.marker(
#                 [28.6138954, 77.2090057],
#                 {}
#             ).addTo(map
