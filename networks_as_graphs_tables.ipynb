# %%
import xarray as xr
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import osmnx

# %%
graph = osmnx.graph_from_place("Yoyogi Park, Shibuya, Tokyo, Japan")

# %%
osmnx.plot_graph(graph)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
gt_intersection, gt_lines = osmnx.graph_to_gdfs(graph)

# %%
gt_intersection
# Out:
#                      y           x  street_count   highway  \
# osmid
# 886196069    35.670087  139.694333             3       NaN
# 886196073    35.669725  139.699508             3       NaN
# 886196100    35.669442  139.699708             3       NaN
# 886196106    35.670422  139.698564             4       NaN
# 886196117    35.671256  139.697470             3       NaN
# ...                ...         ...           ...       ...
# 6567205951   35.667788  139.692075             3       NaN
# 6567205952   35.667736  139.692054             3       NaN
# 6856536019   35.670268  139.695696             3       NaN
# 7684088896   35.674229  139.694659             4       NaN
# 10574987647  35.667951  139.691948             4  crossing
#
#                                geometry
# osmid
# 886196069    POINT (139.69433 35.67009)
# 886196073    POINT (139.69951 35.66972)
# 886196100    POINT (139.69971 35.66944)
# 886196106    POINT (139.69856 35.67042)
# ...

# %%
gt_lines.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 278 entries, (886196069, 1520546857, 0) to (10574987647, 1090844595, 0)
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   osmid     278 non-null    object
#  1   highway   278 non-null    object
#  2   oneway    278 non-null    bool
#  3   reversed  278 non-null    object
#  4   length    278 non-null    float64
#  5   geometry  278 non-null    geometry
#  6   bridge    8 non-null      object
#  7   name      10 non-null     object
#  8   access    2 non-null      object
#  9   lanes     1 non-null      object
#  10  ref       1 non-null      object
#  11  maxspeed  1 non-null      object
# dtypes: bool(1), float64(1), geometry(1), object(9)
# memory usage: 35.0+ KB

# %%
new_graph = osmnx.graph_from_gdfs(gt_intersection, gt_lines)

# %%
osmnx.plot_graph_folium(new_graph)
# Out:
# /var/folders/qk/1gnhnhxn2m91qb1gz4tvnd240000gn/T/ipykernel_16865/882036020.py:1: UserWarning: The `folium` module has been deprecated and will be removed in a future release. You can generate and explore interactive web maps of graph nodes, edges, and/or routes automatically using GeoPandas.GeoDataFrame.explore instead, for example like: `ox.graph_to_gdfs(G, nodes=False).explore()`. See the OSMnx examples gallery for complete details and demonstrations.
#   osmnx.plot_graph_folium(new_graph)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
# ...
